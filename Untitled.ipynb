# %%
pip install firecrawl-py requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from firecrawl import Firecrawl

firecrawl = Firecrawl(api_key="fc-76ea2d86596847afacb01e17ba4db54f")

# %%
# Crawl with scrape options
response = firecrawl.crawl('https://techcrunch.com/category/startups/',
    limit=100,
    scrape_options={
        'formats': [
            'markdown',
            { 'type': 'json', 'schema': { 'type': 'object', 'properties': { 'title': { 'type': 'string' } } } }
        ],
        'proxy': 'auto',
        'maxAge': 600000,
        'onlyMainContent': True
    }
)

# %%
print("Status:", response.status)
print("Top-level metadata:", json.dumps(response.metadata, indent=2))
print("Markdown preview:\n", response.markdown[:1000])
# Out:
# Status: completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 print("Status:", response.status)
# ----> 2 print("Top-level metadata:", json.dumps(response.metadata, indent=2))
#       3 print("Markdown preview:\n", response.markdown[:1000])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pydantic/main.py:892, in BaseModel.__getattr__(self, item)
#     889     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     890 else:
#     891     # this is the current error
# --> 892     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'CrawlJob' object has no attribute 'metadata'

# %%
status = firecrawl.get_crawl_status("3d47bfa6-12b0-46a4-825e-5d3eb9b67f7c")
print(status)
